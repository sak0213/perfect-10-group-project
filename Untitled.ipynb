# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as splt
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# # load dataset

# %%
data_source= pd.read_csv("datasources/athlete_events.csv")
data_source.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
data_source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data_source.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
#data_source.dropna(inplace=True)
data_source["Medal"]=data_source["Medal"].fillna("0")
data_source.dropna()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 0             China  CHN  1992 Summer  1992  Summer       Barcelona
# 1             China  CHN  2012 Summer  2012  Summer          London
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# 5       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# 6       Netherlands  NED  1992 Winter  1992  Winter     Albertville
# ...             ...  ...          ...   ...     ...             ...
# 271111     Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112       Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113       Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114       Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115       Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball     0
# 1                Judo              Judo Men's Extra-Lightweight     0
# 4       Speed Skating          Speed Skating Women's 500 metres     0
# 5       Speed Skating        Speed Skating Women's 1,000 metres     0
# 6       Speed Skating          Speed Skating Women's 500 metres     0
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles     0
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual     0
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team     0
# 271114      Bobsleigh                      Bobsleigh Men's Four     0
# 271115      Bobsleigh                      Bobsleigh Men's Four     0
#
# [206165 rows x 15 columns]

# %%
data_source.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data_source.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.003631 -0.011141 -0.009176  0.011885
# Age    -0.003631  1.000000  0.138246  0.212069 -0.115137
# Height -0.011141  0.138246  1.000000  0.796213  0.047578
# Weight -0.009176  0.212069  0.796213  1.000000  0.019095
# Year    0.011885 -0.115137  0.047578  0.019095  1.000000

# %%
data_source.shape
# Out:
# (271116, 15)

# %% [markdown]
# # Data Visualization

# %%
data_source.Sex.value_counts().plot(kind=("pie"),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
data_source.Team.value_counts().head().plot()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x ="Sex", data = data_source)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
test_data=data_source.groupby(by=["Sex","Team","Sport"] )
test_data.head()
# Out:
#             ID                                  Name Sex   Age  Height  \
# 0            1                             A Dijiang   M  24.0   180.0
# 1            2                              A Lamusi   M  23.0   170.0
# 2            3                   Gunnar Nielsen Aaby   M  24.0     NaN
# 3            4                  Edgar Lindenau Aabye   M  34.0     NaN
# 4            5              Christine Jacoba Aaftink   F  21.0   185.0
# ...        ...                                   ...  ..   ...     ...
# 270944  135490                  Irina Lvovna Zuykova   F  34.0     NaN
# 270973  135502  Nataliya Maratovna "Natasha" Zvereva   F  17.0   172.0
# 270974  135502  Nataliya Maratovna "Natasha" Zvereva   F  17.0   172.0
# 270975  135502  Nataliya Maratovna "Natasha" Zvereva   F  21.0   172.0
# 270976  135502  Nataliya Maratovna "Natasha" Zvereva   F  21.0   172.0
#
#         Weight            Team  NOC        Games  Year  Season       City  \
# 0         80.0           China  CHN  1992 Summer  1992  Summer  Barcelona
# 1         60.0           China  CHN  2012 Summer  2012  Summer     London
# 2          NaN         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 3          NaN  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 4         82.0     Netherlands  NED  1988 Winter  1988  Winter    Calgary
# ...        ...             ...  ...          ...   ...     ...        ...
# 270944     NaN    Unified Team  EUN  1992 Summer  1992  Summer  Barcelona
# 270973    60.0    Soviet Union  URS  1988 Summer  1988  Summer      Seoul
# 270974    60.0    Soviet Union  URS  1988 Summer  1988  Summer      Seoul
# 270975    60.0    Unified Team  EUN  1992 Summer  1992  Summer  Barcelona
# 270976    60.0    Unified Team  EUN  1992 Summer  1992  Summer  Barcelona
#
#                 Sport                                     Event   Medal
# 0          Basketball               Basketball Men's Basketball       0
# 1                Judo              Judo Men's Extra-Lightweight       0
# 2            Football                   Football Men's Football       0
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War    Gold
# 4       Speed Skating          Speed Skating Women's 500 metres       0
# ...               ...                                       ...     ...
# 270944  Equestrianism  Equestrianism Mixed Dressage, Individual       0
# 270973         Tennis                    Tennis Women's Singles       0
# 270974         Tennis                    Tennis Women's Doubles       0
# 270975         Tennis                    Tennis Women's Singles       0
# 270976         Tennis                    Tennis Women's Doubles  Bronze
#
# [30756 rows x 15 columns]

# %%
data_source.groupby(["Sport", "Sex","Team","Medal"]).agg({"Age":["mean"] }).reset_index()
# Out:
#                Sport Sex         Team   Medal        Age
#                                                     mean
# 0        Aeronautics   M  Switzerland    Gold  26.000000
# 1      Alpine Skiing   F      Albania       0  20.000000
# 2      Alpine Skiing   F      Algeria       0  20.000000
# 3      Alpine Skiing   F      Andorra       0  19.814815
# 4      Alpine Skiing   F    Argentina       0  20.666667
# ...              ...  ..          ...     ...        ...
# 12080      Wrestling   M   Yugoslavia       0  25.683333
# 12081      Wrestling   M   Yugoslavia  Bronze  26.333333
# 12082      Wrestling   M   Yugoslavia    Gold  23.000000
# 12083      Wrestling   M   Yugoslavia  Silver  26.833333
# 12084      Wrestling   M       Zambia       0  21.000000
#
# [12085 rows x 5 columns]

# %%
data_source.Team.value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Cinara-13            1
# Oxalis               1
# Verveine-19          1
# Souvenance           1
# Rambo                1
# Name: Team, Length: 1184, dtype: int64

# %%
China= data_source[(data_source["Team"]== "China") & (data_source["Medal"]=="Gold")]
China.Team.value_counts()
# Out:
# China    308
# Name: Team, dtype: int64

# %%
Player_data=data_source[["ID","Sex","Age"]]
Player_data=Player_data.drop_duplicates()
Player_data
# Out:
#             ID Sex   Age
# 0            1   M  24.0
# 1            2   M  23.0
# 2            3   M  24.0
# 3            4   M  34.0
# 4            5   F  21.0
# ...        ...  ..   ...
# 271110  135568   F  33.0
# 271111  135569   M  29.0
# 271112  135570   M  27.0
# 271114  135571   M  30.0
# 271115  135571   M  34.0
#
# [187077 rows x 3 columns]

# %%
Athletescount=len(data_source)
Athletescount
# Out:
# 271116

# %%
Athletescount_df=pd.DataFrame({"Total Athletes":[Athletescount]})
Athletescount_df
# Out:
#    Total Athletes
# 0          271116

# %%
Uniqueitem=data_source.groupby(by=["Name","Year"]).sum()
Uniqueitem
# Out:
#                                                     ID    Age  Height  Weight
# Name                                      Year
#   Gabrielle Marie "Gabby" Adcock (White-) 2016     869   25.0   167.0     0.0
#  Eleonora Margarida Josephina Scmitt      1948  215906   32.0     0.0     0.0
#  Jean Hauptmanns                          1912   46661   26.0     0.0     0.0
#  Luis ngel Fernando de los Santos Grossi  1948   26388   23.0     0.0     0.0
#                                           1952  105552  108.0     0.0     0.0
# ...                                                ...    ...     ...     ...
# zlem Kaya                                 2016   58232   26.0   165.0    47.0
# zman Graud                                1972   40545   33.0   168.0    72.0
# zzet Safer                                2016  104222   26.0   178.0    74.0
# zzet nce                                  2004   52087   23.0   172.0    85.0
#                                           2008   52087   27.0   172.0    85.0
#
# [187237 rows x 4 columns]

# %%
host_country_df=data_source[["City","Year","Season"]]
host_country_df.drop_duplicates().reset_index().sort_values("Year")
# Out:
#     index                    City  Year  Season
# 50   3079                  Athina  1896  Summer
# 3       3                   Paris  1900  Summer
# 44    711               St. Louis  1904  Summer
# 40    268                  Athina  1906  Summer
# 46   1149                  London  1908  Summer
# 13     35               Stockholm  1912  Summer
# 2       2               Antwerpen  1920  Summer
# 43    672                Chamonix  1924  Winter
# 14     39                   Paris  1924  Summer
# 34    133               Amsterdam  1928  Summer
# 45    935            Sankt Moritz  1928  Winter
# 48   1326             Lake Placid  1932  Winter
# 7      26             Los Angeles  1932  Summer
# 49   1327  Garmisch-Partenkirchen  1936  Winter
# 29     94                  Berlin  1936  Summer
# 16     41                  London  1948  Summer
# 47   1187            Sankt Moritz  1948  Winter
# 30    110                    Oslo  1952  Winter
# 9      29                Helsinki  1952  Summer
# 31    111       Cortina d'Ampezzo  1956  Winter
# 51   6194               Stockholm  1956  Summer
# 32    128               Melbourne  1956  Summer
# 22     83            Squaw Valley  1960  Winter
# 33    129                    Roma  1960  Summer
# 23     85               Innsbruck  1964  Winter
# 37    192                   Tokyo  1964  Summer
# 39    266                Grenoble  1968  Winter
# 26     89             Mexico City  1968  Summer
# 27     90                  Munich  1972  Summer
# 41    626                 Sapporo  1972  Winter
# 35    145                Montreal  1976  Summer
# 42    628               Innsbruck  1976  Winter
# 36    188                  Moskva  1980  Summer
# 10     30             Lake Placid  1980  Winter
# 25     88             Los Angeles  1984  Summer
# 24     87                Sarajevo  1984  Winter
# 4       4                 Calgary  1988  Winter
# 28     91                   Seoul  1988  Summer
# 5       6             Albertville  1992  Winter
# 0       0               Barcelona  1992  Summer
# 6       8             Lillehammer  1994  Winter
# 12     32                 Atlanta  1996  Summer
# 17     68                  Nagano  1998  Winter
# 11     31                  Sydney  2000  Summer
# 8      28          Salt Lake City  2002  Winter
# 21     82                  Athina  2004  Summer
# 18     77                  Torino  2006  Winter
# 19     79                 Beijing  2008  Summer
# 38    245               Vancouver  2010  Winter
# 1       1                  London  2012  Summer
# 15     40                   Sochi  2014  Winter
# 20     80          Rio de Janeiro  2016  Summer

# %%
Gendercount=data_source["Sex"].value_counts()
Gendercount
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
Gendercountpercentage=round(Gendercount/Athletescount*100,2)
Gendercountpercentage
# Out:
# M    72.51
# F    27.49
# Name: Sex, dtype: float64

# %%
Count_basedonmedals=(data_source.groupby(["Name"]).count()["Medal"])
Count_basedonmedals
# Out:
# Name
#   Gabrielle Marie "Gabby" Adcock (White-)    1
#  Eleonora Margarida Josephina Scmitt         2
#  Jean Hauptmanns                             1
#  Luis ngel Fernando de los Santos Grossi     5
#  Th Anh                                      1
#                                             ..
# zge Krdar emberci                            1
# zlem Kaya                                    2
# zman Graud                                   1
# zzet Safer                                   1
# zzet nce                                     2
# Name: Medal, Length: 134732, dtype: int64

# %%
Topwinners_df=pd.DataFrame({"Medals count":Count_basedonmedals})
Topwinners_df=Topwinners_df.sort_values("Medals count", ascending=False)
Topwinners_df.head().plot(kind="bar", color="blue")
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
Events_data=data_source[["Sport","Event"]]
Events_data=Events_data.drop_duplicates()
Events_data
# Out:
#                 Sport                                              Event
# 0          Basketball                        Basketball Men's Basketball
# 1                Judo                       Judo Men's Extra-Lightweight
# 2            Football                            Football Men's Football
# 3          Tug-Of-War                        Tug-Of-War Men's Tug-Of-War
# 4       Speed Skating                   Speed Skating Women's 500 metres
# ...               ...                                                ...
# 128473  Weightlifting    Weightlifting Men's All-Around Dumbbell Contest
# 186911        Archery               Archery Men's Au Chapelet, 33 metres
# 186912        Archery            Archery Men's Au Cordon Dore, 33 metres
# 194996        Archery  Archery Men's Target Archery, 28 metres, Indiv...
# 214105    Aeronautics                      Aeronautics Mixed Aeronautics
#
# [765 rows x 2 columns]
